# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

import os
from distutils.dir_util import copy_tree, remove_tree

from PIL import Image
from random import randint

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import balanced_accuracy_score as BAS
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow_addons as tfa
#from tensorflow.keras.utils.vis_utils import plot_model
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, GlobalAveragePooling2D


#from keras.utils import plot_model


print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.5.0

# %%
import shutil

# %%
data_path_CN = "E:/CN_no_crop"

# %%
file = os.listdir(data_path_CN)

# %%
file
# Out:
# ['slide_0a_0.jpg',
#  'slide_0a_1.jpg',
#  'slide_0a_2.jpg',
#  'slide_0a_3.jpg',
#  'slide_0a_4.jpg',
#  'slide_0a_5.jpg',
#  'slide_0a_6.jpg',
#  'slide_0a_7.jpg',
#  'slide_0a_8.jpg',
#  'slide_0a_9.jpg',
#  'slide_0a_10.jpg',
#  'slide_0a_11.jpg',
#  'slide_0a_12.jpg',
#  'slide_0a_13.jpg',
#  'slide_0a_14.jpg',
#  'slide_0a_15.jpg',
#  'slide_0a_16.jpg',
#  'slide_0a_17.jpg',
#  'slide_0a_18.jpg',
#  'slide_0a_19.jpg',
#  'slide_0a_20.jpg',
#  'slide_0a_21.jpg',
#  'slide_0a_22.jpg',
#  'slide_0a_23.jpg',
#  'slide_0a_24.jpg',
#  'slide_0a_25.jpg',
#  'slide_0a_26.jpg',
#  'slide_0a_27.jpg',
#  'slide_0a_28.jpg',
#  'slide_0a_29.jpg',
#  'slide_0a_30.jpg',
#  'slide_0a_31.jpg',
#  'slide_0a_32.jpg',
#  'slide_0a_33.jpg',
#  'slide_0a_34.jpg',
#  'slide_0a_35.jpg',
#  'slide_0a_36.jpg',
#  'slide_0a_37.jpg',
#  'slide_0a_38.jpg',
#  'slide_0a_39.jpg',
#  'slide_0a_40.jpg',
#  'slide_0a_41.jpg',
#  'slide_0a_42.jpg',
#  'slide_0a_43.jpg',
#  'slide_0a_44.jpg',
# ...

# %%
count=[]
for i in file:
    a = i.split('_')[1]
    count.append(a)
print(len(set(count)))
# Out:
# 1280

# %%
jpg_files = [f for f in file if f.endswith('.jpg')]
for i in jpg_files:
    print(i)
# Out:
# slide_0a_0.jpg
# slide_0a_1.jpg
# slide_0a_2.jpg
# slide_0a_3.jpg
# slide_0a_4.jpg
# slide_0a_5.jpg
# slide_0a_6.jpg
# slide_0a_7.jpg
# slide_0a_8.jpg
# slide_0a_9.jpg
# slide_0a_10.jpg
# slide_0a_11.jpg
# slide_0a_12.jpg
# slide_0a_13.jpg
# slide_0a_14.jpg
# slide_0a_15.jpg
# slide_0a_16.jpg
# slide_0a_17.jpg
# slide_0a_18.jpg
# slide_0a_19.jpg
# slide_0a_20.jpg
# slide_0a_21.jpg
# slide_0a_22.jpg
# slide_0a_23.jpg
# slide_0a_24.jpg
# slide_0a_25.jpg
# slide_0a_26.jpg
# slide_0a_27.jpg
# slide_0a_28.jpg
# slide_0a_29.jpg
# slide_0a_30.jpg
# slide_0a_31.jpg
# slide_0a_32.jpg
# slide_0a_33.jpg
# slide_0a_34.jpg
# slide_0a_35.jpg
# slide_0a_36.jpg
# slide_0a_37.jpg
# slide_0a_38.jpg
# slide_0a_39.jpg
# slide_0a_40.jpg
# slide_0a_41.jpg
# slide_0a_42.jpg
# slide_0a_43.jpg
# slide_0a_44.jpg
# slide_0a_45.jpg
# slide_0a_46.jpg
# slide_0a_47.jpg
# slide_1a_0.jpg
# slide_1a_1.jpg
# slide_1a_2.jpg
# slide_1a_3.jpg
# slide_1a_4.jpg
# slide_1a_5.jpg
# slide_1a_6.jpg
# slide_1a_7.jpg
# ...

# %%
file[0].split('_')[1]
# Out:
# '0a'

# %%
for i in file:
    if not os.path.exists("E:/CN_no_crop/" + str(i.split('_')[1])):
        os.makedirs("E:/CN_no_crop/" + str(i.split('_')[1]))

# %%
for filename in file:
    # 提取文件名中的数字
    number = filename.split('_')[1]
    # 构建目标文件夹路径
    target_folder = os.path.join("E:/CN_no_crop/", number)

    # 构建源文件路径
    source_path = os.path.join("E:/CN_no_crop/", filename)
    # 移动文件到目标文件夹
    shutil.move(source_path, target_folder)

print("Files moved successfully.")
# Out:
# Files moved successfully.

# %%
file
# Out:
# ['slide_18_0.jpg',
#  'slide_18_1.jpg',
#  'slide_18_10.jpg',
#  'slide_18_11.jpg',
#  'slide_18_12.jpg',
#  'slide_18_13.jpg',
#  'slide_18_14.jpg',
#  'slide_18_15.jpg',
#  'slide_18_16.jpg',
#  'slide_18_17.jpg',
#  'slide_18_18.jpg',
#  'slide_18_19.jpg',
#  'slide_18_2.jpg',
#  'slide_18_20.jpg',
#  'slide_18_21.jpg',
#  'slide_18_22.jpg',
#  'slide_18_23.jpg',
#  'slide_18_24.jpg',
#  'slide_18_25.jpg',
#  'slide_18_26.jpg',
#  'slide_18_27.jpg',
#  'slide_18_28.jpg',
#  'slide_18_29.jpg',
#  'slide_18_3.jpg',
#  'slide_18_30.jpg',
#  'slide_18_31.jpg',
#  'slide_18_32.jpg',
#  'slide_18_33.jpg',
#  'slide_18_34.jpg',
#  'slide_18_35.jpg',
#  'slide_18_36.jpg',
#  'slide_18_37.jpg',
#  'slide_18_38.jpg',
#  'slide_18_39.jpg',
#  'slide_18_4.jpg',
#  'slide_18_40.jpg',
#  'slide_18_41.jpg',
#  'slide_18_42.jpg',
#  'slide_18_43.jpg',
#  'slide_18_44.jpg',
#  'slide_18_45.jpg',
#  'slide_18_46.jpg',
#  'slide_18_47.jpg',
#  'slide_18_48.jpg',
#  'slide_18_5.jpg',
# ...
